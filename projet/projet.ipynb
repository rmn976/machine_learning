# %%
import warnings
import pandas as pd 
import numpy as np 
import seaborn as sns
import sklearn as sklearn
import matplotlib.pyplot as plt
# %matplotlib inline
warnings.simplefilter('ignore')

# %%
# Affichage du dataset
df = pd.read_csv('train.csv', sep=';'); df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
# Taille du dataset
df.shape
# Out:
# (45211, 17)

# %%
# Remplacement des données binaire par 0 et 1
df['y'].replace(('yes', 'no'), (1, 0), inplace=True)
df['default'].replace(('yes', 'no'), (1, 0), inplace=True)
df['housing'].replace(('yes', 'no'), (1, 0), inplace=True)
df['loan'].replace(('yes', 'no'), (1, 0), inplace=True)

# %%
# Encodage des données catégorielles avec sklearn encoder
from sklearn import preprocessing
lb = preprocessing.LabelEncoder()
df['job'] = lb.fit_transform(df['job'])
df['marital'] = lb.fit_transform(df['marital'])
df['education'] = lb.fit_transform(df['education'])
df['contact'] = lb.fit_transform(df['contact'])
df['month'] = lb.fit_transform(df['month'])
df['poutcome'] = lb.fit_transform(df['poutcome'])
df.head()
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   58    4        1          2        0     2143        1     0        2
# 1   44    9        2          1        0       29        1     0        2
# 2   33    2        1          1        0        2        1     1        2
# 3   47    1        1          3        0     1506        1     0        2
# 4   33   11        2          3        0        1        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  y
# 0    5      8       261         1     -1         0         3  0
# 1    5      8       151         1     -1         0         3  0
# 2    5      8        76         1     -1         0         3  0
# 3    5      8        92         1     -1         0         3  0
# 4    5      8       198         1     -1         0         3  0

# %%
# Statistiques descriptives du dataset
df.describe()
# Out:
#                 age           job       marital     education       default  \
# count  45211.000000  45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210      4.339762      1.167725      1.224813      0.018027
# std       10.618762      3.272657      0.608230      0.747997      0.133049
# min       18.000000      0.000000      0.000000      0.000000      0.000000
# 25%       33.000000      1.000000      1.000000      1.000000      0.000000
# 50%       39.000000      4.000000      1.000000      1.000000      0.000000
# 75%       48.000000      7.000000      2.000000      2.000000      0.000000
# max       95.000000     11.000000      2.000000      3.000000      1.000000
#
#              balance       housing          loan       contact           day  \
# count   45211.000000  45211.000000  45211.000000  45211.000000  45211.000000
# mean     1362.272058      0.555838      0.160226      0.640242     15.806419
# ...

# %%
# Visualisation en boîte à moustache de la feature 'age'
plt.figure(figsize=(16, 5))
sns.boxplot(x="age", data=df)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
# Visualisation en boîte à moustache de la feature 'balance'
plt.figure(figsize=(16, 5))
sns.boxplot(x="balance", data=df)
# Out:
# <AxesSubplot:xlabel='balance'>

# %%
# Visualisation en boîte à moustache de la feature 'duration'
plt.figure(figsize=(16, 5))
sns.boxplot(x="duration", data=df)
# Out:
# <AxesSubplot:xlabel='duration'>

# %%
# Visualisation en boîte à moustache de la feature 'campaign'
plt.figure(figsize=(16, 5))
sns.boxplot(x="campaign", data=df)
# Out:
# <AxesSubplot:xlabel='campaign'>

# %%
# Visualisation en boîte à moustache de la feature 'pdays'
plt.figure(figsize=(16, 5))
sns.boxplot(x="pdays", data=df)
# Out:
# <AxesSubplot:xlabel='pdays'>

# %%
# Visualisation en boîte à moustache de la feature 'previous'
plt.figure(figsize=(16, 5))
sns.boxplot(x="previous", data=df)
# Out:
# <AxesSubplot:xlabel='previous'>

# %%
# Visualisation en boîte à moustache de la feature 'poutcome'
plt.figure(figsize=(16, 5))
sns.boxplot(x="poutcome", data=df)
# Out:
# <AxesSubplot:xlabel='poutcome'>

# %%
# Exemple de données retirées du dataset
over70 = df['age'] > 70
df_over70 = df[over70]
df_over70.shape
# Out:
# (487, 17)

# %%
# Suppression des valeurs abérantes représentant moins de 5% du dataset
filter1 = df['age'] < 70
df = df[filter1]
filter2 = df['balance'] < 3000
df = df[filter2]
filter3 = df['balance'] > -1500
df = df[filter3]
filter4 = df['duration'] < 800
df = df[filter4]
filter5 = df['campaign'] < 8
df = df[filter5]
print(df.shape)
# Out:
# (35527, 17)

# %%
# Heatmap des corrélations
f, ax = plt.subplots(figsize=(20,7))
sns.heatmap(df.iloc[:,-15:].corr(), annot=True, ax =ax)
# Out:
# <AxesSubplot:>

# %%
# On définit X avec les features en entrée
X = df[['age', 'job', 'marital', 'education', 'default', 'balance', 'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays', 'previous', 'poutcome']]
X.head()
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   58    4        1          2        0     2143        1     0        2
# 1   44    9        2          1        0       29        1     0        2
# 2   33    2        1          1        0        2        1     1        2
# 3   47    1        1          3        0     1506        1     0        2
# 4   33   11        2          3        0        1        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome
# 0    5      8       261         1     -1         0         3
# 1    5      8       151         1     -1         0         3
# 2    5      8        76         1     -1         0         3
# 3    5      8        92         1     -1         0         3
# 4    5      8       198         1     -1         0         3

# %%
# On définit y avec la classe servant de résultat
y = df[['y']]
y.shape
# Out:
# (35527, 1)

# %%
# On split nos datas pour avoir des set d'entrainement et de test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (26645, 16)
# (8882, 16)
# (26645, 1)
# (8882, 1)

# %% [markdown]
# # Algo 1

# %%
# On crée notre classifier Random Forest avec 2 paramètres
from sklearn.ensemble import RandomForestClassifier
clf1 = RandomForestClassifier(n_estimators= 100, max_depth= 50)

# On entraine notre model
clf1.fit(X_train, y_train)
y_pred = clf1.predict(X_test)

# %%
# Accuracy de notre classifier
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.927606394956091

# %%
from sklearn import metrics
from pandas import DataFrame
import matplotlib.pyplot as plt 
prob_score = clf1.predict_proba(X_test)
prob_score = DataFrame(prob_score).iloc[:,0]
fpr,tpr,thresholds = metrics.roc_curve(y_test,1-prob_score)

# %%
test_fpr, test_tpr, _ = metrics.roc_curve(y_test.values, y_pred)
test_auc = np.round(metrics.auc(test_fpr, test_tpr), 3)

# %%
plt.plot(test_fpr,test_tpr, color = 'darkorange')
plt.xlim([-.05, 1.05])
plt.ylim([-.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve')
plt.show()

# %%
test_fpr = np.insert(test_fpr, 0, 0)
test_tpr = np.insert(test_tpr, 0, 0)

fig, ax = plt.subplots(figsize=(8, 6))
#ax.plot(train_fpr, train_tpr, label='Train AUC: ' + str(train_auc))
ax.plot(test_fpr, test_tpr, label='Test AUC: ' + str(test_auc))
#ax.plot(test_fpr, test_tpr, 'k--', label='Chance Curve')
ax.set_xlabel('False Positive Rate', fontsize=12)
ax.set_ylabel('True Positive Rate', fontsize=12)
ax.grid(True)
ax.legend(fontsize=12)
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
y_pred = clf1.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()

# %%
importances = clf1.feature_importances_
importances
# Out:
# array([0.10607759, 0.05192518, 0.02421953, 0.02957667, 0.00269227,
#        0.11346756, 0.03245641, 0.01096584, 0.02133213, 0.09507472,
#        0.09759165, 0.22695306, 0.03729135, 0.06228855, 0.02402776,
#        0.06405971])

# %%
feature_imp = pd.Series(importances, index=X.columns.tolist()).sort_values(ascending=False)
feature_imp
# Out:
# duration     0.226953
# balance      0.113468
# age          0.106078
# month        0.097592
# day          0.095075
# poutcome     0.064060
# pdays        0.062289
# job          0.051925
# campaign     0.037291
# housing      0.032456
# education    0.029577
# marital      0.024220
# previous     0.024028
# contact      0.021332
# loan         0.010966
# default      0.002692
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16, 9))
sns.barplot(x=feature_imp, y=feature_imp.index)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Algo 2

# %%
# On crée notre classifier Random Forest avec 2 paramètres
from sklearn.ensemble import RandomForestClassifier
clf2 = RandomForestClassifier(n_estimators= 500, criterion = 'entropy')

# On entraine notre model
clf2.fit(X_train, y_train)
y_pred = clf2.predict(X_test)

# %%
# Accuracy de notre classifier
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9280567439765819

# %%
from sklearn import metrics
from pandas import DataFrame
import matplotlib.pyplot as plt 
prob_score = clf2.predict_proba(X_test)
prob_score = DataFrame(prob_score).iloc[:,0]
fpr,tpr,thresholds = metrics.roc_curve(y_test,1-prob_score)

# %%
test_fpr, test_tpr, _ = metrics.roc_curve(y_test.values, y_pred)
test_auc = np.round(metrics.auc(test_fpr, test_tpr), 3)

# %%
plt.plot(test_fpr,test_tpr, color = 'darkorange')
plt.xlim([-.05, 1.05])
plt.ylim([-.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve')
plt.show()

# %%
test_fpr = np.insert(test_fpr, 0, 0)
test_tpr = np.insert(test_tpr, 0, 0)

fig, ax = plt.subplots(figsize=(8, 6))
#ax.plot(train_fpr, train_tpr, label='Train AUC: ' + str(train_auc))
ax.plot(test_fpr, test_tpr, label='Test AUC: ' + str(test_auc))
#ax.plot(test_fpr, test_tpr, 'k--', label='Chance Curve')
ax.set_xlabel('False Positive Rate', fontsize=12)
ax.set_ylabel('True Positive Rate', fontsize=12)
ax.grid(True)
ax.legend(fontsize=12)
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
y_pred = clf2.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()

# %%
importances = clf2.feature_importances_
importances
# Out:
# array([0.09723777, 0.04857468, 0.02215276, 0.02742248, 0.00205058,
#        0.10508643, 0.03297757, 0.01142456, 0.03809784, 0.08940125,
#        0.09701756, 0.25645449, 0.03552795, 0.05641819, 0.02621855,
#        0.05393733])

# %%
feature_imp = pd.Series(importances, index=X.columns.tolist()).sort_values(ascending=False)
feature_imp
# Out:
# duration     0.256454
# balance      0.105086
# age          0.097238
# month        0.097018
# day          0.089401
# pdays        0.056418
# poutcome     0.053937
# job          0.048575
# contact      0.038098
# campaign     0.035528
# housing      0.032978
# education    0.027422
# previous     0.026219
# marital      0.022153
# loan         0.011425
# default      0.002051
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16, 9))
sns.barplot(x=feature_imp, y=feature_imp.index)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Feature selection

# %%
X1 = df[['age', 'balance', 'day', 'month', 'duration']]
X1.head()
from sklearn.model_selection import train_test_split
X1_train, X1_test, y1_train, y1_test = train_test_split( X1, y)

print(X1_train.shape)
print(X1_test.shape)
print(y1_train.shape)
print(y1_test.shape)
# Out:
# (26645, 5)
# (8882, 5)
# (26645, 1)
# (8882, 1)

# %%
# On crée notre classifier Random Forest avec 2 paramètres
from sklearn.ensemble import RandomForestClassifier
clf1 = RandomForestClassifier(n_estimators= 100, max_depth= 50)

# On entraine notre model
clf1.fit(X1_train, y1_train)
y1_pred = clf1.predict(X1_test)

# %%
# Accuracy de notre classifier
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y1_test, y1_pred))
# Out:
# Accuracy: 0.9136455753208736

# %%
from sklearn import metrics
from pandas import DataFrame
import matplotlib.pyplot as plt 
prob_score = clf1.predict_proba(X1_test)
prob_score = DataFrame(prob_score).iloc[:,0]
fpr,tpr,thresholds = metrics.roc_curve(y1_test,1-prob_score)

# %%
test_fpr, test_tpr, _ = metrics.roc_curve(y1_test.values, y1_pred)
test_auc = np.round(metrics.auc(test_fpr, test_tpr), 3)

# %%
plt.plot(test_fpr,test_tpr, color = 'darkorange')
plt.xlim([-.05, 1.05])
plt.ylim([-.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve')
plt.show()

# %%
test_fpr = np.insert(test_fpr, 0, 0)
test_tpr = np.insert(test_tpr, 0, 0)

fig, ax = plt.subplots(figsize=(8, 6))
#ax.plot(train_fpr, train_tpr, label='Train AUC: ' + str(train_auc))
ax.plot(test_fpr, test_tpr, label='Test AUC: ' + str(test_auc))
#ax.plot(test_fpr, test_tpr, 'k--', label='Chance Curve')
ax.set_xlabel('False Positive Rate', fontsize=12)
ax.set_ylabel('True Positive Rate', fontsize=12)
ax.grid(True)
ax.legend(fontsize=12)
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
y1_pred = clf1.predict(X1_test)
cm = confusion_matrix(y1_test, y1_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()
